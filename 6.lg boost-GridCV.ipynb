# %%
import lightgbm

# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV
param_grid={"num_leaves": [31, 63, 127], "max_depth": [-1, 3, 5], "subsample": [0.8, 1.0], "colsample_bytree": [0.8, 1.0],
            'n_estimators':[50,100,200,500], 'learning_rate':[0.1,0.2,0.03]}
grid=GridSearchCV(LGBMRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000166 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 313
# [LightGBM] [Info] Number of data points in the train set: 1338, number of used features: 5
# [LightGBM] [Info] Start training from score 13270.422260
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# C:\Users\Raji\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Raji\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\Raji\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raji\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\Raji\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# GridSearchCV(estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 1.0],
#                          'learning_rate': [0.1, 0.2, 0.03],
#                          'max_depth': [-1, 3, 5],
#                          'n_estimators': [50, 100, 200, 500],
#                          'num_leaves': [31, 63, 127], 'subsample': [0.8, 1.0]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 31, 'subsample': 0.8}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.135711      0.019523         0.004627        0.000815
# 1         0.112866      0.003461         0.003532        0.000779
# 2         0.141086      0.001704         0.002725        0.000875
# 3         0.148386      0.004723         0.003469        0.000966
# 4         0.160448      0.004762         0.002358        0.000633
# ..             ...           ...              ...             ...
# 427       0.597622      0.031050         0.003913        0.000221
# 428       0.603971      0.027488         0.004831        0.000672
# 429       0.626488      0.031254         0.004905        0.000770
# 430       0.621577      0.022100         0.004464        0.000816
# 431       0.565528      0.032825         0.005957        0.001404
#
#      param_colsample_bytree  param_learning_rate  param_max_depth  \
# 0                       0.8                 0.10               -1
# 1                       0.8                 0.10               -1
# 2                       0.8                 0.10               -1
# 3                       0.8                 0.10               -1
# 4                       0.8                 0.10               -1
# ..                      ...                  ...              ...
# 427                     1.0                 0.03                5
# 428                     1.0                 0.03                5
# 429                     1.0                 0.03                5
# 430                     1.0                 0.03                5
# 431                     1.0                 0.03                5
#
#      param_n_estimators  param_num_leaves  param_subsample  \
# 0                    50                31              0.8
# 1                    50                31              1.0
# 2                    50                63              0.8
# 3                    50                63              1.0
# 4                    50               127              0.8
# ..                  ...               ...              ...
# 427                 500                31              1.0
# 428                 500                63              0.8
# 429                 500                63              1.0
# 430                 500               127              0.8
# 431                 500               127              1.0
#
#                                                 params  split0_test_score  \
# 0    {'colsample_bytree': 0.8, 'learning_rate': 0.1...           0.870905
# 1    {'colsample_bytree': 0.8, 'learning_rate': 0.1...           0.870905
# 2    {'colsample_bytree': 0.8, 'learning_rate': 0.1...           0.867932
# 3    {'colsample_bytree': 0.8, 'learning_rate': 0.1...           0.867932
# 4    {'colsample_bytree': 0.8, 'learning_rate': 0.1...           0.867932
# ..                                                 ...                ...
# 427  {'colsample_bytree': 1.0, 'learning_rate': 0.0...           0.870598
# 428  {'colsample_bytree': 1.0, 'learning_rate': 0.0...           0.870598
# 429  {'colsample_bytree': 1.0, 'learning_rate': 0.0...           0.870598
# 430  {'colsample_bytree': 1.0, 'learning_rate': 0.0...           0.870598
# 431  {'colsample_bytree': 1.0, 'learning_rate': 0.0...           0.870598
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.797926           0.874960           0.841016
# 1             0.797926           0.874960           0.841016
# 2             0.791633           0.875416           0.841270
# 3             0.791633           0.875416           0.841270
# 4             0.791633           0.875416           0.841270
# ..                 ...                ...                ...
# 427           0.792126           0.881981           0.841273
# 428           0.792126           0.881981           0.841273
# 429           0.792126           0.881981           0.841273
# 430           0.792126           0.881981           0.841273
# 431           0.792126           0.881981           0.841273
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.852002         0.847362        0.027647              181
# 1             0.852002         0.847362        0.027647              181
# 2             0.851602         0.845571        0.029512              197
# 3             0.851602         0.845571        0.029512              197
# 4             0.851602         0.845571        0.029512              197
# ..                 ...              ...             ...              ...
# 427           0.851287         0.847453        0.031119              175
# 428           0.851287         0.847453        0.031119              175
# 429           0.851287         0.847453        0.031119              175
# 430           0.851287         0.847453        0.031119              175
# 431           0.851287         0.847453        0.031119              175
#
# [432 rows x 19 columns]

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 34
# BMI: 23
# Children: 1
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[6421.78578186]
