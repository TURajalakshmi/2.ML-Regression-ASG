# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent, test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
Param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features':['sqrt','log2'],'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(), Param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Users\Raji\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.041527      0.006325         0.004258        0.001169
# 1        0.199837      0.007676         0.008879        0.001014
# 2        0.021259      0.000786         0.003167        0.001145
# 3        0.200672      0.005835         0.008828        0.000865
# 4        0.055639      0.003603         0.002608        0.000739
# 5        0.495879      0.007047         0.007965        0.001041
# 6        0.053160      0.001439         0.002315        0.000398
# 7        0.498367      0.007024         0.007994        0.001300
# 8        0.021521      0.001164         0.002713        0.000879
# 9        0.188073      0.004140         0.008063        0.001379
# 10       0.021235      0.001110         0.002020        0.000024
# 11       0.192028      0.006734         0.007979        0.001101
# 12       0.030642      0.001619         0.002394        0.000541
# 13       0.282605      0.007796         0.008977        0.000815
# 14       0.030914      0.000855         0.002424        0.000814
# 15       0.265130      0.004032         0.008059        0.002093
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                 100
# 2    squared_error               log2                  10
# 3    squared_error               log2                 100
# 4   absolute_error               sqrt                  10
# 5   absolute_error               sqrt                 100
# 6   absolute_error               log2                  10
# 7   absolute_error               log2                 100
# 8     friedman_mse               sqrt                  10
# 9     friedman_mse               sqrt                 100
# 10    friedman_mse               log2                  10
# 11    friedman_mse               log2                 100
# 12         poisson               sqrt                  10
# 13         poisson               sqrt                 100
# 14         poisson               log2                  10
# 15         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.845642
# 1   {'criterion': 'squared_error', 'max_features':...           0.867609
# 2   {'criterion': 'squared_error', 'max_features':...           0.856075
# 3   {'criterion': 'squared_error', 'max_features':...           0.865472
# 4   {'criterion': 'absolute_error', 'max_features'...           0.837492
# 5   {'criterion': 'absolute_error', 'max_features'...           0.862278
# 6   {'criterion': 'absolute_error', 'max_features'...           0.838298
# 7   {'criterion': 'absolute_error', 'max_features'...           0.861384
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.853508
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.867773
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.836193
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.862355
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.831758
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.864519
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.855444
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.858749
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.779084           0.796127           0.810021
# 1            0.784656           0.813915           0.831899
# 2            0.754260           0.797948           0.808895
# 3            0.790671           0.809259           0.827231
# 4            0.772800           0.783382           0.811389
# 5            0.785142           0.810222           0.829700
# 6            0.770390           0.772907           0.811263
# 7            0.795751           0.809469           0.826023
# 8            0.778698           0.783249           0.817293
# 9            0.793343           0.811625           0.822396
# 10           0.746402           0.794886           0.791250
# 11           0.790008           0.808853           0.829282
# 12           0.778329           0.793998           0.807241
# 13           0.790793           0.802662           0.827738
# 14           0.755697           0.791047           0.800838
# 15           0.792752           0.805671           0.826685
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.770113         0.800198        0.026567                9
# 1            0.771880         0.813992        0.034145                2
# 2            0.749622         0.793360        0.039083               12
# 3            0.772591         0.813045        0.031942                3
# 4            0.754815         0.791975        0.029227               15
# 5            0.772900         0.812048        0.031920                5
# 6            0.771688         0.792909        0.027403               13
# 7            0.771216         0.812769        0.030220                4
# 8            0.755228         0.797595        0.034270               10
# 9            0.776343         0.814296        0.031023                1
# 10           0.749099         0.783566        0.033244               16
# 11           0.769730         0.812046        0.031983                6
# 12           0.764930         0.795251        0.023168               11
# 13           0.766175         0.810377        0.033555                8
# 14           0.759676         0.792540        0.035960               14
# 15           0.775946         0.811961        0.028676                7

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 35
# BMI: 27
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[46657.1516834]

# %%
import pickle
filename="finalized_model_Random Forest.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_Random Forest.sav",'rb'))
result=loaded_model.predict([[35,28.88,0,1,1]])
result
